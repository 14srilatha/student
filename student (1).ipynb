# %%
#import neccessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
#read the dataset
train_df=pd.read_csv("C:\\Users\\vsris\\Downloads\\student_spending (1).csv")
test_df=pd.read_csv("C:\\Users\\vsris\\Downloads\\student_spending (1).csv")

# %%
#to know what are the colums in your dataset
train_df.columns
# Out:
# Index(['Unnamed: 0', 'age', 'gender', 'year_in_school', 'major',
#        'monthly_income', 'financial_aid', 'tuition', 'housing', 'food',
#        'transportation', 'books_supplies', 'entertainment', 'personal_care',
#        'technology', 'health_wellness', 'miscellaneous',
#        'preferred_payment_method'],
#       dtype='object')

# %%
train_df=pd.read_csv('C:\\Users\\vsris\\Downloads\\student_spending (1).csv', index_col=[0])

# %%
train_df.columns
# Out:
# Index(['age', 'gender', 'year_in_school', 'major', 'monthly_income',
#        'financial_aid', 'tuition', 'housing', 'food', 'transportation',
#        'books_supplies', 'entertainment', 'personal_care', 'technology',
#        'health_wellness', 'miscellaneous', 'preferred_payment_method'],
#       dtype='object')

# %%
#Top 5 rows in your dataset
train_df.head()
# Out:
#    age      gender year_in_school             major  monthly_income  \
# 0   19  Non-binary       Freshman        Psychology             958
# 1   24      Female         Junior         Economics            1006
# 2   24  Non-binary         Junior         Economics             734
# 3   23      Female         Senior  Computer Science             617
# 4   20      Female         Senior  Computer Science             810
#
#    financial_aid  tuition  housing  food  transportation  books_supplies  \
# 0            270     5939      709   296             123             188
# 1            875     4908      557   365              85             252
# 2            928     3051      666   220             137              99
# 3            265     4935      652   289             114             223
# 4            522     3887      825   372             168             194
#
#    entertainment  personal_care  technology  health_wellness  miscellaneous  \
# 0             41             78         134              127             72
# 1             74             92         226              129             68
# 2            130             23         239              112            133
# 3             99             30         163              105             55
# 4             48             71          88               71            104
#
#   preferred_payment_method
# 0        Credit/Debit Card
# 1        Credit/Debit Card
# 2                     Cash
# 3       Mobile Payment App
# 4        Credit/Debit Card

# %%
#bottom 5 rows in your dataset
train_df.tail()
# Out:
#      age      gender year_in_school             major  monthly_income  \
# 995   22      Female         Senior           Biology            1346
# 996   19      Female         Senior           Biology            1407
# 997   20        Male         Junior         Economics             957
# 998   22  Non-binary         Senior         Economics            1174
# 999   24  Non-binary      Sophomore  Computer Science             541
#
#      financial_aid  tuition  housing  food  transportation  books_supplies  \
# 995            520     3688      969   152             194             151
# 996            560     3380      508   265              52             206
# 997            393     3497      723   339             139              69
# 998            612     3649      543   237             123             200
# 999            640     5965      609   270             191             215
#
#      entertainment  personal_care  technology  health_wellness  miscellaneous  \
# 995             42             38         252               65            163
# 996             40             98         274               84            135
# 997            112             46         284               57             28
# 998            129             90         190              101             65
# 999            139             43         281               88            145
#
#     preferred_payment_method
# 995                     Cash
# 996       Mobile Payment App
# 997       Mobile Payment App
# 998       Mobile Payment App
# 999                     Cash

# %%
train_df.head(10)
# Out:
#    age      gender year_in_school             major  monthly_income  \
# 0   19  Non-binary       Freshman        Psychology             958
# 1   24      Female         Junior         Economics            1006
# 2   24  Non-binary         Junior         Economics             734
# 3   23      Female         Senior  Computer Science             617
# 4   20      Female         Senior  Computer Science             810
# 5   25  Non-binary      Sophomore  Computer Science             523
# 6   23      Female       Freshman       Engineering            1354
# 7   23      Female         Junior         Economics             631
# 8   22  Non-binary         Senior  Computer Science            1402
# 9   18      Female         Junior  Computer Science            1423
#
#    financial_aid  tuition  housing  food  transportation  books_supplies  \
# 0            270     5939      709   296             123             188
# 1            875     4908      557   365              85             252
# 2            928     3051      666   220             137              99
# 3            265     4935      652   289             114             223
# 4            522     3887      825   372             168             194
# 5            790     3151      413   386             122             131
# 6             69     4973      812   398             101             213
# 7            748     3966      571   269              92             251
# 8            248     5638      599   354              82             155
# 9             74     3977      626   249             117             123
#
#    entertainment  personal_care  technology  health_wellness  miscellaneous  \
# 0             41             78         134              127             72
# 1             74             92         226              129             68
# 2            130             23         239              112            133
# 3             99             30         163              105             55
# 4             48             71          88               71            104
# 5             73             38         234              108             99
# 6             21             38         157              117             48
# 7             37             90         152               56             62
# 8            123             41         162              172            194
# 9             51             74         243               34            196
#
#   preferred_payment_method
# 0        Credit/Debit Card
# 1        Credit/Debit Card
# 2                     Cash
# 3       Mobile Payment App
# 4        Credit/Debit Card
# 5       Mobile Payment App
# 6        Credit/Debit Card
# 7       Mobile Payment App
# 8        Credit/Debit Card
# 9       Mobile Payment App

# %%
#how does the data looks
print(train_df.shape)#total rows x column count
print("/n")
print(train_df.dtypes)#each column datatype
# Out:
# (1000, 17)
# /n
# age                          int64
# gender                      object
# year_in_school              object
# major                       object
# monthly_income               int64
# financial_aid                int64
# tuition                      int64
# housing                      int64
# food                         int64
# transportation               int64
# books_supplies               int64
# entertainment                int64
# personal_care                int64
# technology                   int64
# health_wellness              int64
# miscellaneous                int64
# preferred_payment_method    object
# dtype: object

# %%
#info gives count and datatype of it
train_df.info()
print('_'*40)
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       1000 non-null   int64
#  1   gender                    1000 non-null   object
#  2   year_in_school            1000 non-null   object
#  3   major                     1000 non-null   object
#  4   monthly_income            1000 non-null   int64
#  5   financial_aid             1000 non-null   int64
#  6   tuition                   1000 non-null   int64
#  7   housing                   1000 non-null   int64
#  8   food                      1000 non-null   int64
#  9   transportation            1000 non-null   int64
#  10  books_supplies            1000 non-null   int64
#  11  entertainment             1000 non-null   int64
#  12  personal_care             1000 non-null   int64
#  13  technology                1000 non-null   int64
#  14  health_wellness           1000 non-null   int64
#  15  miscellaneous             1000 non-null   int64
#  16  preferred_payment_method  1000 non-null   object
# dtypes: int64(13), object(4)
# memory usage: 140.6+ KB
# ________________________________________
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                1000 non-null   int64
#  1   age                       1000 non-null   int64
#  2   gender                    1000 non-null   object
#  3   year_in_school            1000 non-null   object
#  4   major                     1000 non-null   object
#  5   monthly_income            1000 non-null   int64
#  6   financial_aid             1000 non-null   int64
#  7   tuition                   1000 non-null   int64
#  8   housing                   1000 non-null   int64
#  9   food                      1000 non-null   int64
#  10  transportation            1000 non-null   int64
#  11  books_supplies            1000 non-null   int64
#  12  entertainment             1000 non-null   int64
#  13  personal_care             1000 non-null   int64
#  14  technology                1000 non-null   int64
#  15  health_wellness           1000 non-null   int64
#  16  miscellaneous             1000 non-null   int64
#  17  preferred_payment_method  1000 non-null   object
# dtypes: int64(14), object(4)
# memory usage: 140.8+ KB

# %%
# finding duplicate values in a dataset
train_df.duplicated().sum()
# Out:
# 0

# %%
#identifiying garbage values
for i in train_df.select_dtypes(include="object").columns:
    print(train_df[i].value_counts())
    print("!!!!"*5)
# Out:
# Male          356
# Female        323
# Non-binary    321
# Name: gender, dtype: int64
# !!!!!!!!!!!!!!!!!!!!
# Senior       254
# Freshman     253
# Junior       247
# Sophomore    246
# Name: year_in_school, dtype: int64
# !!!!!!!!!!!!!!!!!!!!
# Biology             228
# Economics           204
# Computer Science    192
# Engineering         192
# Psychology          184
# Name: major, dtype: int64
# !!!!!!!!!!!!!!!!!!!!
# Mobile Payment App    350
# Credit/Debit Card     340
# Cash                  310
# Name: preferred_payment_method, dtype: int64
# !!!!!!!!!!!!!!!!!!!!

# %%
#EXPLORATARY DATA ANALYSIS(EDA)
#describe function used to find the total count,mean,standard deviation ,maximum value,minimum value
#25,50,75 persentage of the dataset value
train_df.describe()
# Out:
#                age  monthly_income  financial_aid      tuition     housing  \
# count  1000.000000     1000.000000    1000.000000  1000.000000  1000.00000
# mean     21.675000     1020.650000     504.771000  4520.395000   696.00600
# std       2.322664      293.841161     287.092575   860.657944   171.21862
# min      18.000000      501.000000       0.000000  3003.000000   401.00000
# 25%      20.000000      770.750000     261.000000  3779.750000   538.75000
# 50%      22.000000     1021.000000     513.000000  4547.500000   704.50000
# 75%      24.000000     1288.250000     751.500000  5285.000000   837.25000
# max      25.000000     1500.000000    1000.000000  6000.000000  1000.00000
#
#               food  transportation  books_supplies  entertainment  \
# count  1000.000000      1000.00000     1000.000000    1000.000000
# mean    252.642000       124.63700      174.761000      84.814000
# std      86.949606        43.55799       72.404518      37.970451
# min     100.000000        50.00000       50.000000      20.000000
# 25%     175.000000        88.00000      112.000000      54.000000
# 50%     255.000000       123.00000      175.000000      86.000000
# 75%     330.000000       162.25000      238.000000     116.000000
# max     400.000000       200.00000      300.000000     150.000000
#
#        personal_care   technology  health_wellness  miscellaneous
# count    1000.000000  1000.000000      1000.000000    1000.000000
# mean       60.699000   178.304000       114.310000     108.910000
# std        22.898007    71.744441        49.591544      52.412221
# min        20.000000    50.000000        30.000000      20.000000
# 25%        41.000000   114.000000        73.000000      63.750000
# 50%        62.000000   178.000000       115.000000     110.000000
# 75%        80.000000   241.000000       158.000000     153.000000
# max       100.000000   300.000000       200.000000     200.000000

# %%
train_df.describe(include="object")
# Out:
#        gender year_in_school    major preferred_payment_method
# count    1000           1000     1000                     1000
# unique      3              4        5                        3
# top      Male         Senior  Biology       Mobile Payment App
# freq      356            254      228                      350

# %%
#histogram to understand the distribution
for i in train_df.select_dtypes(include="number").columns:
    sns.histplot(data=train_df,x=i)
    plt.show()

# %%
#box plots to identify outliers
for i in train_df.select_dtypes(include="number").columns:
    sns.boxplot(data=train_df,x=i)
    plt.show()

# %%
#scatter plot to understand the relationship
for i in ['age', 'gender', 'year_in_school', 'major', 'monthly_income',
       'tuition', 'housing', 'food', 'transportation',
       'books_supplies', 'entertainment', 'personal_care', 'technology',
       'health_wellness', 'miscellaneous', 'preferred_payment_method']:
    sns.scatterplot(data=train_df,x=i,y='financial_aid')
    plt.show()

# %%
#correlation with heat map to interepret the relation and multicolliniarity
import warnings
warnings.filterwarnings("ignore")
train_df.corr()
# Out:
#                       age  monthly_income  financial_aid   tuition   housing  \
# age              1.000000       -0.015448      -0.022263  0.037042  0.023288
# monthly_income  -0.015448        1.000000       0.037050 -0.000149  0.004471
# financial_aid   -0.022263        0.037050       1.000000  0.008536 -0.008199
# tuition          0.037042       -0.000149       0.008536  1.000000 -0.020992
# housing          0.023288        0.004471      -0.008199 -0.020992  1.000000
# food             0.029906       -0.018521       0.017463 -0.019216 -0.038335
# transportation  -0.015375        0.046152       0.017674  0.036734 -0.001975
# books_supplies   0.025567        0.003527      -0.048570 -0.009433 -0.009936
# entertainment    0.060446        0.024454       0.014249 -0.036925  0.021142
# personal_care   -0.052414        0.006842      -0.010427 -0.039074  0.014577
# technology       0.005633        0.010084       0.017912 -0.007864 -0.017230
# health_wellness -0.025031       -0.032567       0.024430  0.010978 -0.006323
# miscellaneous    0.003904       -0.023902      -0.002977 -0.014844  0.013337
#
#                      food  transportation  books_supplies  entertainment  \
# age              0.029906       -0.015375        0.025567       0.060446
# monthly_income  -0.018521        0.046152        0.003527       0.024454
# financial_aid    0.017463        0.017674       -0.048570       0.014249
# tuition         -0.019216        0.036734       -0.009433      -0.036925
# housing         -0.038335       -0.001975       -0.009936       0.021142
# food             1.000000       -0.003443        0.075485       0.012960
# transportation  -0.003443        1.000000        0.012900       0.008505
# books_supplies   0.075485        0.012900        1.000000       0.004742
# entertainment    0.012960        0.008505        0.004742       1.000000
# personal_care    0.047422        0.048892       -0.037669      -0.023282
# technology       0.034033       -0.003910        0.019464       0.012152
# health_wellness -0.003700        0.024824        0.000030      -0.032671
# miscellaneous    0.005192        0.032136       -0.001294      -0.019109
#
#                  personal_care  technology  health_wellness  miscellaneous
# age                  -0.052414    0.005633        -0.025031       0.003904
# monthly_income        0.006842    0.010084        -0.032567      -0.023902
# financial_aid        -0.010427    0.017912         0.024430      -0.002977
# tuition              -0.039074   -0.007864         0.010978      -0.014844
# housing               0.014577   -0.017230        -0.006323       0.013337
# food                  0.047422    0.034033        -0.003700       0.005192
# transportation        0.048892   -0.003910         0.024824       0.032136
# books_supplies       -0.037669    0.019464         0.000030      -0.001294
# entertainment        -0.023282    0.012152        -0.032671      -0.019109
# personal_care         1.000000    0.050225         0.004207      -0.014038
# technology            0.050225    1.000000        -0.025953       0.005714
# health_wellness       0.004207   -0.025953         1.000000      -0.024968
# miscellaneous        -0.014038    0.005714        -0.024968       1.000000

# %%
a=train_df.corr()

# %%
plt.figure(figsize=(20,20))
sns.heatmap(a,annot=True)
# Out:
# <Axes: >

# %%
#choose the method of imputing missing value
#like mean,median,mode or KNNIputer
train_df.isnull().sum()#there is no null values in this dataset
# Out:
# age                         0
# gender                      0
# year_in_school              0
# major                       0
# monthly_income              0
# financial_aid               0
# tuition                     0
# housing                     0
# food                        0
# transportation              0
# books_supplies              0
# entertainment               0
# personal_care               0
# technology                  0
# health_wellness             0
# miscellaneous               0
# preferred_payment_method    0
# dtype: int64

# %%
train_df=train_df.drop(['age','year_in_school','major','preferred_payment_method'],axis=1)
train_df.head()
# Out:
#        gender  monthly_income  financial_aid  tuition  housing  food  \
# 0  Non-binary             958            270     5939      709   296
# 1      Female            1006            875     4908      557   365
# 2  Non-binary             734            928     3051      666   220
# 3      Female             617            265     4935      652   289
# 4      Female             810            522     3887      825   372
#
#    transportation  books_supplies  entertainment  personal_care  technology  \
# 0             123             188             41             78         134
# 1              85             252             74             92         226
# 2             137              99            130             23         239
# 3             114             223             99             30         163
# 4             168             194             48             71          88
#
#    health_wellness  miscellaneous
# 0              127             72
# 1              129             68
# 2              112            133
# 3              105             55
# 4               71            104

# %%
def removecountryoutlier(value):
    if value not in ['female', 'male']:
        return '0'
    else:
        return '1'

train_df['gender'] = train_df['gender'].apply(removecountryoutlier)
train_df['gender'].value_counts()
# Out:
# 0    1000
# Name: gender, dtype: int64

# %%
train_df.head(10)
# Out:
#   gender  monthly_income  financial_aid  tuition  housing  food  \
# 0      0             958            270     5939      709   296
# 1      0            1006            875     4908      557   365
# 2      0             734            928     3051      666   220
# 3      0             617            265     4935      652   289
# 4      0             810            522     3887      825   372
# 5      0             523            790     3151      413   386
# 6      0            1354             69     4973      812   398
# 7      0             631            748     3966      571   269
# 8      0            1402            248     5638      599   354
# 9      0            1423             74     3977      626   249
#
#    transportation  books_supplies  entertainment  personal_care  technology  \
# 0             123             188             41             78         134
# 1              85             252             74             92         226
# 2             137              99            130             23         239
# 3             114             223             99             30         163
# 4             168             194             48             71          88
# 5             122             131             73             38         234
# 6             101             213             21             38         157
# 7              92             251             37             90         152
# 8              82             155            123             41         162
# 9             117             123             51             74         243
#
#    health_wellness  miscellaneous
# 0              127             72
# 1              129             68
# 2              112            133
# 3              105             55
# 4               71            104
# 5              108             99
# 6              117             48
# 7               56             62
# 8              172            194
# 9               34            196

# %%
x = train_df.drop('financial_aid',axis=1)
y= train_df['financial_aid']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
predictions=lr.predict(x_test)

# %%
lir=LinearRegression()
lir.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=lir.predict(x_test)
print(y_predict)
print(y_test)
# Out:
# [490.56597698 484.3305174  517.04613799 467.00126694 529.64227894
#  509.57340058 484.4818791  551.17223957 488.92251798 531.50276926
#  487.66010435 493.85963485 457.3361112  473.77593566 485.39208785
#  506.70294604 448.90109009 531.67824156 488.54523641 541.11079991
#  502.18589779 506.16281726 445.0913409  487.30651859 471.92335006
#  453.24988419 477.26357151 517.41919947 507.72942459 496.31248001
#  527.24085171 489.79401944 471.67777267 498.68793781 497.99768803
#  488.25053433 464.55046077 478.58518853 507.40402837 464.61040573
#  508.385537   462.42673903 487.87030968 478.57061277 506.06347584
#  521.40495571 532.35427081 517.13033695 517.97149628 491.82965025
#  548.00238365 507.73872975 481.54826566 504.62290572 509.99139
#  449.47856129 513.56540784 498.70385888 503.69068509 499.212882
#  446.37243537 499.6630938  501.52306494 486.57268217 454.05398529
#  472.08360295 455.87883452 503.45591768 492.4321253  531.27461488
#  534.26120084 499.42753205 492.80586617 511.74755727 525.06033743
#  509.27358066 486.31381314 516.20727665 489.12261416 501.61862748
#  533.93037487 520.28972053 472.75700318 475.91046798 472.61762665
#  511.68138374 499.22221327 478.2390648  537.18577175 504.62237358
#  530.36129864 456.29350801 489.8531957  486.38811051 499.21508095
#  489.12707498 528.43611582 505.38479994 483.50924063 473.59528078
#  473.23432359 462.49938077 529.05188185 509.96753731 506.0193989
#  537.45056567 507.44643711 500.32101647 520.78624503 520.09619031
#  493.92094251 469.11351941 535.95963168 479.4767435  459.39865935
#  502.84283072 461.7270458  478.91299199 464.57722774 491.89523665
#  525.06714981 516.15858235 504.9756168  528.92054393 518.31403237
#  490.7114514  475.45072121 478.47281176 521.23723572 535.57910821
#  486.69318712 522.78213094 499.70992966 493.54499886 454.69259172
#  470.00701048 491.63381876 483.85471475 506.4709537  563.4285973
#  509.72045721 494.19540971 474.04229089 450.41791155 511.61965749
#  536.66572004 474.7621433  483.81445109 493.41208851 503.03820096
#  521.96146907 508.07799989 514.940861   513.2106731  474.25314195
#  495.55896424 470.55737175 495.08514457 497.66320175 507.30407914
#  522.37187141 504.4824585  494.12239478 507.74536995 477.62946362
#  490.5787947  517.02100599 472.10771934 487.15337944 491.33774061
#  496.00811583 491.60662143 517.71802184 464.71726762 472.88944305
#  489.65948927 493.72703023 528.52805213 496.35655365 476.92369289
#  489.11987946 477.34494886 472.77505692 512.60124719 520.42469974
#  495.04249585 499.9799001  488.36978228 464.90184404 486.57958403
#  518.15274259 530.73564426 486.53182219 554.24111797 520.84770595
#  453.79882068 487.36843724 510.59854763 516.61074408 485.16317619]
# 217    550
# 874    533
# 792     46
# 133    993
# 574     72
#       ...
# 143    466
# 51     479
# 873    465
# 478    204
# 646    534
# Name: financial_aid, Length: 200, dtype: int64

# %%
print('coefficient of determination: %.3f' % r2_score(y_test,y_predict))
# Out:
# coefficient of determination: -0.025

# %%
from sklearn.metrics import r2_score
print(f"R squared:{r2_score(y_test,y_predict)}")
# Out:
# R squared:-0.024748262682853683

# %%
diff = y_test - predictions

# %%
import seaborn as sns
sns.distplot(diff)
# Out:
# <Axes: xlabel='financial_aid', ylabel='Density'>

# %%
import pickle
pickle.dump(lr, open('./predicted.sav', 'wb'))

# %%
from joblib import dump
dump(predictions,"regg.pkl")
# Out:
# ['regg.pkl']
